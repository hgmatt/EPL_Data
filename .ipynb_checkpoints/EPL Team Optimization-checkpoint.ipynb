# %%
#Load MyPrettyPrinter
# %run MyPrettyPrinter
# %matplotlib inline

#Load EPL Data from fantasy.premierleague.com
# %run getDataPL

#import cPickle as pickle
#date_text = '2016_07_27'
#players = pickle.load(open(date_text + '_player_data.p'))
#all_data = pickle.load(open(date_text + '_all_data.p'))
# Out:
# 2016_08_04

# %%
MyPrettyPrinter().pprint(all_data[1])
# Out:
# {assists: 0,
#  bonus: 15,
#  bps: 705,
#  chance_of_playing_next_round: None,
#  chance_of_playing_this_round: None,
#  clean_sheets: 16,
#  code: 11334,
#  cost_change_event: 0,
#  cost_change_event_fall: 0,
#  cost_change_start: 0,
#  cost_change_start_fall: 0,
#  creativity: 20.0,
#  dreamteam_count: 0,
#  ea_index: 409,
#  element_type: 1,
#  ep_next: 4.5,
#  ep_this: None,
#  event_points: 0,
#  first_name: Petr,
#  'fixtures': [{code: 855173,
#                difficulty: 3,
#                event: 1,
#                event_name: Gameweek 1,
#                finished: False,
#                finished_provisional: False,
#                id: 8,
#                is_home: True,
#                kickoff_time: 2016-08-14T15:00:00Z,
#                kickoff_time_formatted: 14 Aug 16:00,
#                minutes: 0,
#                opponent_name: Liverpool,
#                opponent_short_name: LIV,
#                provisional_start_time: False,
#                team_a: 9,
#                team_a_score: None,
#                team_h: 1,
#                team_h_score: None},
#               {code: 855182,
#                difficulty: 5,
#                event: 2,
#                event_name: Gameweek 2,
#                finished: False,
#                finished_provisional: False,
#                id: 13,
#                is_home: False,
#                kickoff_time: 2016-08-20T16:30:00Z,
#                kickoff_time_formatted: 20 Aug 17:30,
#                minutes: 0,
#                opponent_name: Leicester,
#                opponent_short_name: LEI,
#                provisional_start_time: False,
#                team_a: 1,
#                team_a_score: None,
#                team_h: 8,
#                team_h_score: None},
#               {code: 855200,
#                difficulty: 1,
#                event: 3,
#                event_name: Gameweek 3,
#                finished: False,
#                finished_provisional: False,
#                id: 28,
#                is_home: False,
#                kickoff_time: 2016-08-27T14:00:00Z,
#                kickoff_time_formatted: 27 Aug 15:00,
#                minutes: 0,
#                opponent_name: Watford,
#                opponent_short_name: WAT,
#                provisional_start_time: False,
#                team_a: 1,
#                team_a_score: None,
#                team_h: 18,
#                team_h_score: None},
#               {code: 855203,
#                difficulty: 3,
#                event: 4,
#                event_name: Gameweek 4,
#                finished: False,
#                finished_provisional: False,
#                id: 31,
#                is_home: True,
#                kickoff_time: 2016-09-10T14:00:00Z,
#                kickoff_time_formatted: 10 Sep 15:00,
#                minutes: 0,
#                opponent_name: Southampton,
#                opponent_short_name: SOU,
#                provisional_start_time: False,
#                team_a: 13,
#                team_a_score: None,
#                team_h: 1,
#                team_h_score: None},
#               {code: 855215,
#                difficulty: 1,
#                event: 5,
#                event_name: Gameweek 5,
#                finished: False,
#                finished_provisional: False,
#                id: 43,
#                is_home: False,
#                kickoff_time: 2016-09-17T14:00:00Z,
#                kickoff_time_formatted: 17 Sep 15:00,
#                minutes: 0,
#                opponent_name: Hull,
#                opponent_short_name: HUL,
#                provisional_start_time: False,
#                team_a: 1,
#                team_a_score: None,
#                team_h: 7,
#                team_h_score: None},
#               {code: 855223,
#                difficulty: 3,
#                event: 6,
#                event_name: Gameweek 6,
#                finished: False,
#                finished_provisional: False,
#                id: 51,
#                is_home: True,
#                kickoff_time: 2016-09-24T16:30:00Z,
#                kickoff_time_formatted: 24 Sep 17:30,
#                minutes: 0,
#                opponent_name: Chelsea,
#                opponent_short_name: CHE,
#                provisional_start_time: False,
#                team_a: 4,
#                team_a_score: None,
#                team_h: 1,
#                team_h_score: None},
#               {code: 855232,
#                difficulty: 1,
#                event: 7,
#                event_name: Gameweek 7,
#                finished: False,
#                finished_provisional: False,
#                id: 61,
#                is_home: False,
#                kickoff_time: 2016-10-01T14:00:00Z,
#                kickoff_time_formatted: 01 Oct 15:00,
#                minutes: 0,
#                opponent_name: Burnley,
#                opponent_short_name: BUR,
#                provisional_start_time: False,
#                team_a: 1,
#                team_a_score: None,
#                team_h: 3,
#                team_h_score: None},
#               {code: 855243,
#                difficulty: 1,
#                event: 8,
#                event_name: Gameweek 8,
#                finished: False,
#                finished_provisional: False,
#                id: 71,
#                is_home: True,
#                kickoff_time: 2016-10-15T14:00:00Z,
#                kickoff_time_formatted: 15 Oct 15:00,
#                minutes: 0,
#                opponent_name: Swansea,
#                opponent_short_name: SWA,
#                provisional_start_time: False,
#                team_a: 16,
#                team_a_score: None,
#                team_h: 1,
#                team_h_score: None},
#               {code: 855253,
#                difficulty: 1,
#                event: 9,
#                event_name: Gameweek 9,
#                finished: False,
#                finished_provisional: False,
#                id: 81,
#                is_home: True,
#                kickoff_time: 2016-10-22T14:00:00Z,
#                kickoff_time_formatted: 22 Oct 15:00,
#                minutes: 0,
#                opponent_name: Middlesbrough,
#                opponent_short_name: MID,
#                provisional_start_time: False,
#                team_a: 12,
#                team_a_score: None,
#                team_h: 1,
#                team_h_score: None},
#               {code: 855268,
#                difficulty: 1,
#                event: 10,
#                event_name: Gameweek 10,
#                finished: False,
#                finished_provisional: False,
#                id: 97,
#                is_home: False,
#                kickoff_time: 2016-10-29T14:00:00Z,
#                kickoff_time_formatted: 29 Oct 15:00,
#                minutes: 0,
#                opponent_name: Sunderland,
#                opponent_short_name: SUN,
#                provisional_start_time: False,
#                team_a: 1,
#                team_a_score: None,
#                team_h: 15,
#                team_h_score: None},
#               {code: 855273,
#                difficulty: 4,
#                event: 11,
#                event_name: Gameweek 11,
#                finished: False,
#                finished_provisional: False,
#                id: 101,
#                is_home: True,
#                kickoff_time: 2016-11-05T15:00:00Z,
#                kickoff_time_formatted: 05 Nov 15:00,
#                minutes: 0,
#                opponent_name: Spurs,
#                opponent_short_name: TOT,
#                provisional_start_time: False,
#                team_a: 17,
#                team_a_score: None,
#                team_h: 1,
#                team_h_score: None},
#               {code: 855284,
#                difficulty: 5,
#                event: 12,
#                event_name: Gameweek 12,
#                finished: False,
#                finished_provisional: False,
#                id: 113,
#                is_home: False,
#                kickoff_time: 2016-11-19T15:00:00Z,
#                kickoff_time_formatted: 19 Nov 15:00,
#                minutes: 0,
#                opponent_name: Man Utd,
#                opponent_short_name: MUN,
#                provisional_start_time: False,
#                team_a: 1,
#                team_a_score: None,
#                team_h: 11,
#                team_h_score: None},
#               {code: 855292,
#                difficulty: 1,
#                event: 13,
#                event_name: Gameweek 13,
#                finished: False,
#                finished_provisional: False,
#                id: 121,
#                is_home: True,
#                kickoff_time: 2016-11-26T15:00:00Z,
#                kickoff_time_formatted: 26 Nov 15:00,
#                minutes: 0,
#                opponent_name: Bournemouth,
#                opponent_short_name: BOU,
#                provisional_start_time: False,
#                team_a: 2,
#                team_a_score: None,
#                team_h: 1,
#                team_h_score: None},
#               {code: 855311,
#                difficulty: 3,
#                event: 14,
#                event_name: Gameweek 14,
#                finished: False,
#                finished_provisional: False,
#                id: 140,
#                is_home: False,
#                kickoff_time: 2016-12-03T15:00:00Z,
#                kickoff_time_formatted: 03 Dec 15:00,
#                minutes: 0,
#                opponent_name: West Ham,
#                opponent_short_name: WHU,
#                provisional_start_time: False,
#                team_a: 1,
#                team_a_score: None,
#                team_h: 20,
#                team_h_score: None},
#               {code: 855312,
#                difficulty: 2,
#                event: 15,
#                event_name: Gameweek 15,
#                finished: False,
#                finished_provisional: False,
#                id: 141,
#                is_home: True,
#                kickoff_time: 2016-12-10T15:00:00Z,
#                kickoff_time_formatted: 10 Dec 15:00,
#                minutes: 0,
#                opponent_name: Stoke,
#                opponent_short_name: STK,
#                provisional_start_time: False,
#                team_a: 14,
#                team_a_score: None,
#                team_h: 1,
#                team_h_score: None},
#               {code: 855328,
#                difficulty: 2,
#                event: 16,
#                event_name: Gameweek 16,
#                finished: False,
#                finished_provisional: False,
#                id: 156,
#                is_home: False,
#                kickoff_time: 2016-12-14T19:45:00Z,
#                kickoff_time_formatted: 14 Dec 19:45,
#                minutes: 0,
#                opponent_name: Everton,
#                opponent_short_name: EVE,
#                provisional_start_time: False,
#                team_a: 1,
#                team_a_score: None,
#                team_h: 6,
#                team_h_score: None},
#               {code: 855335,
#                difficulty: 4,
#                event: 17,
#                event_name: Gameweek 17,
#                finished: False,
#                finished_provisional: False,
#                id: 164,
#                is_home: False,
#                kickoff_time: 2016-12-17T15:00:00Z,
#                kickoff_time_formatted: 17 Dec 15:00,
#                minutes: 0,
#                opponent_name: Man City,
#                opponent_short_name: MCI,
#                provisional_start_time: False,
#                team_a: 1,
#                team_a_score: None,
#                team_h: 10,
#                team_h_score: None},
#               {code: 855342,
#                difficulty: 1,
#                event: 18,
#                event_name: Gameweek 18,
#                finished: False,
#                finished_provisional: False,
#                id: 171,
#                is_home: True,
#                kickoff_time: 2016-12-26T15:00:00Z,
#                kickoff_time_formatted: 26 Dec 15:00,
#                minutes: 0,
#                opponent_name: West Brom,
#                opponent_short_name: WBA,
#                provisional_start_time: False,
#                team_a: 19,
#                team_a_score: None,
#                team_h: 1,
#                team_h_score: None},
#               {code: 855352,
#                difficulty: 1,
#                event: 19,
#                event_name: Gameweek 19,
#                finished: False,
#                finished_provisional: False,
#                id: 181,
#                is_home: True,
#                kickoff_time: 2016-12-31T15:00:00Z,
#                kickoff_time_formatted: 31 Dec 15:00,
#                minutes: 0,
#                opponent_name: Crystal Palace,
#                opponent_short_name: CRY,
#                provisional_start_time: False,
#                team_a: 5,
#                team_a_score: None,
#                team_h: 1,
#                team_h_score: None},
#               {code: 855362,
#                difficulty: 1,
#                event: 20,
#                event_name: Gameweek 20,
#                finished: False,
#                finished_provisional: False,
#                id: 191,
#                is_home: False,
#                kickoff_time: 2017-01-02T15:00:00Z,
#                kickoff_time_formatted: 02 Jan 15:00,
#                minutes: 0,
#                opponent_name: Bournemouth,
#                opponent_short_name: BOU,
#                provisional_start_time: False,
#                team_a: 1,
#                team_a_score: None,
#                team_h: 2,
#                team_h_score: None},
#               {code: 855378,
#                difficulty: 2,
#                event: 21,
#                event_name: Gameweek 21,
#                finished: False,
#                finished_provisional: False,
#                id: 207,
#                is_home: False,
#                kickoff_time: 2017-01-14T15:00:00Z,
#                kickoff_time_formatted: 14 Jan 15:00,
#                minutes: 0,
#                opponent_name: Swansea,
#                opponent_short_name: SWA,
#                provisional_start_time: False,
#                team_a: 1,
#                team_a_score: None,
#                team_h: 16,
#                team_h_score: None},
#               {code: 855383,
#                difficulty: 1,
#                event: 22,
#                event_name: Gameweek 22,
#                finished: False,
#                finished_provisional: False,
#                id: 211,
#                is_home: True,
#                kickoff_time: 2017-01-21T15:00:00Z,
#                kickoff_time_formatted: 21 Jan 15:00,
#                minutes: 0,
#                opponent_name: Burnley,
#                opponent_short_name: BUR,
#                provisional_start_time: False,
#                team_a: 3,
#                team_a_score: None,
#                team_h: 1,
#                team_h_score: None},
#               {code: 855393,
#                difficulty: 1,
#                event: 23,
#                event_name: Gameweek 23,
#                finished: False,
#                finished_provisional: False,
#                id: 221,
#                is_home: True,
#                kickoff_time: 2017-01-31T19:45:00Z,
#                kickoff_time_formatted: 31 Jan 19:45,
#                minutes: 0,
#                opponent_name: Watford,
#                opponent_short_name: WAT,
#                provisional_start_time: False,
#                team_a: 18,
#                team_a_score: None,
#                team_h: 1,
#                team_h_score: None},
#               {code: 855402,
#                difficulty: 3,
#                event: 24,
#                event_name: Gameweek 24,
#                finished: False,
#                finished_provisional: False,
#                id: 231,
#                is_home: False,
#                kickoff_time: 2017-02-04T15:00:00Z,
#                kickoff_time_formatted: 04 Feb 15:00,
#                minutes: 0,
#                opponent_name: Chelsea,
#                opponent_short_name: CHE,
#                provisional_start_time: False,
#                team_a: 1,
#                team_a_score: None,
#                team_h: 4,
#                team_h_score: None},
#               {code: 855413,
#                difficulty: 1,
#                event: 25,
#                event_name: Gameweek 25,
#                finished: False,
#                finished_provisional: False,
#                id: 241,
#                is_home: True,
#                kickoff_time: 2017-02-11T15:00:00Z,
#                kickoff_time_formatted: 11 Feb 15:00,
#                minutes: 0,
#                opponent_name: Hull,
#                opponent_short_name: HUL,
#                provisional_start_time: False,
#                team_a: 7,
#                team_a_score: None,
#                team_h: 1,
#                team_h_score: None},
#               {code: 855428,
#                difficulty: 3,
#                event: 26,
#                event_name: Gameweek 26,
#                finished: False,
#                finished_provisional: False,
#                id: 257,
#                is_home: False,
#                kickoff_time: 2017-02-25T15:00:00Z,
#                kickoff_time_formatted: 25 Feb 15:00,
#                minutes: 0,
#                opponent_name: Southampton,
#                opponent_short_name: SOU,
#                provisional_start_time: False,
#                team_a: 1,
#                team_a_score: None,
#                team_h: 13,
#                team_h_score: None},
#               {code: 855433,
#                difficulty: 3,
#                event: 27,
#                event_name: Gameweek 27,
#                finished: False,
#                finished_provisional: False,
#                id: 262,
#                is_home: False,
#                kickoff_time: 2017-03-04T15:00:00Z,
#                kickoff_time_formatted: 04 Mar 15:00,
#                minutes: 0,
#                opponent_name: Liverpool,
#                opponent_short_name: LIV,
#                provisional_start_time: False,
#                team_a: 1,
#                team_a_score: None,
#                team_h: 9,
#                team_h_score: None},
#               {code: 855443,
#                difficulty: 4,
#                event: 28,
#                event_name: Gameweek 28,
#                finished: False,
#                finished_provisional: False,
#                id: 271,
#                is_home: True,
#                kickoff_time: 2017-03-11T15:00:00Z,
#                kickoff_time_formatted: 11 Mar 15:00,
#                minutes: 0,
#                opponent_name: Leicester,
#                opponent_short_name: LEI,
#                provisional_start_time: False,
#                team_a: 8,
#                team_a_score: None,
#                team_h: 1,
#                team_h_score: None},
#               {code: 855460,
#                difficulty: 2,
#                event: 29,
#                event_name: Gameweek 29,
#                finished: False,
#                finished_provisional: False,
#                id: 289,
#                is_home: False,
#                kickoff_time: 2017-03-18T15:00:00Z,
#                kickoff_time_formatted: 18 Mar 15:00,
#                minutes: 0,
#                opponent_name: West Brom,
#                opponent_short_name: WBA,
#                provisional_start_time: False,
#                team_a: 1,
#                team_a_score: None,
#                team_h: 19,
#                team_h_score: None},
#               {code: 855462,
#                difficulty: 3,
#                event: 30,
#                event_name: Gameweek 30,
#                finished: False,
#                finished_provisional: False,
#                id: 291,
#                is_home: True,
#                kickoff_time: 2017-04-01T14:00:00Z,
#                kickoff_time_formatted: 01 Apr 15:00,
#                minutes: 0,
#                opponent_name: Man City,
#                opponent_short_name: MCI,
#                provisional_start_time: False,
#                team_a: 10,
#                team_a_score: None,
#                team_h: 1,
#                team_h_score: None},
#               {code: 855472,
#                difficulty: 3,
#                event: 31,
#                event_name: Gameweek 31,
#                finished: False,
#                finished_provisional: False,
#                id: 301,
#                is_home: True,
#                kickoff_time: 2017-04-04T18:45:00Z,
#                kickoff_time_formatted: 04 Apr 19:45,
#                minutes: 0,
#                opponent_name: West Ham,
#                opponent_short_name: WHU,
#                provisional_start_time: False,
#                team_a: 20,
#                team_a_score: None,
#                team_h: 1,
#                team_h_score: None},
#               {code: 855483,
#                difficulty: 1,
#                event: 32,
#                event_name: Gameweek 32,
#                finished: False,
#                finished_provisional: False,
#                id: 312,
#                is_home: False,
#                kickoff_time: 2017-04-08T14:00:00Z,
#                kickoff_time_formatted: 08 Apr 15:00,
#                minutes: 0,
#                opponent_name: Crystal Palace,
#                opponent_short_name: CRY,
#                provisional_start_time: False,
#                team_a: 1,
#                team_a_score: None,
#                team_h: 5,
#                team_h_score: None},
#               {code: 855495,
#                difficulty: 1,
#                event: 33,
#                event_name: Gameweek 33,
#                finished: False,
#                finished_provisional: False,
#                id: 324,
#                is_home: False,
#                kickoff_time: 2017-04-15T14:00:00Z,
#                kickoff_time_formatted: 15 Apr 15:00,
#                minutes: 0,
#                opponent_name: Middlesbrough,
#                opponent_short_name: MID,
#                provisional_start_time: False,
#                team_a: 1,
#                team_a_score: None,
#                team_h: 12,
#                team_h_score: None},
#               {code: 855503,
#                difficulty: 1,
#                event: 34,
#                event_name: Gameweek 34,
#                finished: False,
#                finished_provisional: False,
#                id: 331,
#                is_home: True,
#                kickoff_time: 2017-04-22T14:00:00Z,
#                kickoff_time_formatted: 22 Apr 15:00,
#                minutes: 0,
#                opponent_name: Sunderland,
#                opponent_short_name: SUN,
#                provisional_start_time: False,
#                team_a: 15,
#                team_a_score: None,
#                team_h: 1,
#                team_h_score: None},
#               {code: 855519,
#                difficulty: 4,
#                event: 35,
#                event_name: Gameweek 35,
#                finished: False,
#                finished_provisional: False,
#                id: 348,
#                is_home: False,
#                kickoff_time: 2017-04-29T14:00:00Z,
#                kickoff_time_formatted: 29 Apr 15:00,
#                minutes: 0,
#                opponent_name: Spurs,
#                opponent_short_name: TOT,
#                provisional_start_time: False,
#                team_a: 1,
#                team_a_score: None,
#                team_h: 17,
#                team_h_score: None},
#               {code: 855523,
#                difficulty: 3,
#                event: 36,
#                event_name: Gameweek 36,
#                finished: False,
#                finished_provisional: False,
#                id: 351,
#                is_home: True,
#                kickoff_time: 2017-05-06T14:00:00Z,
#                kickoff_time_formatted: 06 May 15:00,
#                minutes: 0,
#                opponent_name: Man Utd,
#                opponent_short_name: MUN,
#                provisional_start_time: False,
#                team_a: 11,
#                team_a_score: None,
#                team_h: 1,
#                team_h_score: None},
#               {code: 855537,
#                difficulty: 2,
#                event: 37,
#                event_name: Gameweek 37,
#                finished: False,
#                finished_provisional: False,
#                id: 366,
#                is_home: False,
#                kickoff_time: 2017-05-13T14:00:00Z,
#                kickoff_time_formatted: 13 May 15:00,
#                minutes: 0,
#                opponent_name: Stoke,
#                opponent_short_name: STK,
#                provisional_start_time: False,
#                team_a: 1,
#                team_a_score: None,
#                team_h: 14,
#                team_h_score: None},
#               {code: 855542,
#                difficulty: 3,
#                event: 38,
#                event_name: Gameweek 38,
#                finished: False,
#                finished_provisional: False,
#                id: 371,
#                is_home: True,
#                kickoff_time: 2017-05-21T14:00:00Z,
#                kickoff_time_formatted: 21 May 15:00,
#                minutes: 0,
#                opponent_name: Everton,
#                opponent_short_name: EVE,
#                provisional_start_time: False,
#                team_a: 6,
#                team_a_score: None,
#                team_h: 1,
#                team_h_score: None}],
#  form: 0.0,
#  goals_conceded: 31,
#  goals_scored: 0,
#  'history_past': [{assists: 0,
#                    bonus: 1,
#                    bps: 0,
#                    clean_sheets: 0,
#                    creativity: 0.0,
#                    ea_index: 0,
#                    element_code: 11334,
#                    end_cost: 64,
#                    goals_conceded: 9,
#                    goals_scored: 0,
#                    ict_index: 0.0,
#                    id: 115,
#                    influence: 0.0,
#                    minutes: 1714,
#                    own_goals: 0,
#                    penalties_missed: 0,
#                    penalties_saved: 0,
#                    red_cards: 0,
#                    saves: 58,
#                    season: 1,
#                    season_name: 2006/07,
#                    start_cost: 65,
#                    threat: 0.0,
#                    total_points: 98,
#                    yellow_cards: 1},
#                   {assists: 0,
#                    bonus: 2,
#                    bps: 0,
#                    clean_sheets: 0,
#                    creativity: 0.0,
#                    ea_index: 0,
#                    element_code: 11334,
#                    end_cost: 65,
#                    goals_conceded: 17,
#                    goals_scored: 0,
#                    ict_index: 0.0,
#                    id: 807,
#                    influence: 0.0,
#                    minutes: 2313,
#                    own_goals: 0,
#                    penalties_missed: 0,
#                    penalties_saved: 0,
#                    red_cards: 0,
#                    saves: 60,
#                    season: 2,
#                    season_name: 2007/08,
#                    start_cost: 65,
#                    threat: 0.0,
#                    total_points: 120,
#                    yellow_cards: 0},
#                   {assists: 0,
#                    bonus: 7,
#                    bps: 0,
#                    clean_sheets: 0,
#                    creativity: 0.0,
#                    ea_index: 0,
#                    element_code: 11334,
#                    end_cost: 60,
#                    goals_conceded: 24,
#                    goals_scored: 0,
#                    ict_index: 0.0,
#                    id: 1426,
#                    influence: 0.0,
#                    minutes: 3150,
#                    own_goals: 0,
#                    penalties_missed: 0,
#                    penalties_saved: 1,
#                    red_cards: 0,
#                    saves: 87,
#                    season: 3,
#                    season_name: 2008/09,
#                    start_cost: 60,
#                    threat: 0.0,
#                    total_points: 171,
#                    yellow_cards: 0},
#                   {assists: 1,
#                    bonus: 0,
#                    bps: 0,
#                    clean_sheets: 0,
#                    creativity: 0.0,
#                    ea_index: 0,
#                    element_code: 11334,
#                    end_cost: 62,
#                    goals_conceded: 26,
#                    goals_scored: 0,
#                    ict_index: 0.0,
#                    id: 2156,
#                    influence: 0.0,
#                    minutes: 3020,
#                    own_goals: 1,
#                    penalties_missed: 0,
#                    penalties_saved: 1,
#                    red_cards: 1,
#                    saves: 66,
#                    season: 4,
#                    season_name: 2009/10,
#                    start_cost: 65,
#                    threat: 0.0,
#                    total_points: 144,
#                    yellow_cards: 0},
#                   {assists: 1,
#                    bonus: 2,
#                    bps: 0,
#                    clean_sheets: 15,
#                    creativity: 0.0,
#                    ea_index: 0,
#                    element_code: 11334,
#                    end_cost: 67,
#                    goals_conceded: 33,
#                    goals_scored: 0,
#                    ict_index: 0.0,
#                    id: 2829,
#                    influence: 0.0,
#                    minutes: 3420,
#                    own_goals: 0,
#                    penalties_missed: 0,
#                    penalties_saved: 1,
#                    red_cards: 0,
#                    saves: 98,
#                    season: 5,
#                    season_name: 2010/11,
#                    start_cost: 65,
#                    threat: 0.0,
#                    total_points: 158,
#                    yellow_cards: 0},
#                   {assists: 0,
#                    bonus: 7,
#                    bps: 0,
#                    clean_sheets: 10,
#                    creativity: 0.0,
#                    ea_index: 399,
#                    element_code: 11334,
#                    end_cost: 68,
#                    goals_conceded: 39,
#                    goals_scored: 0,
#                    ict_index: 0.0,
#                    id: 3319,
#                    influence: 0.0,
#                    minutes: 3060,
#                    own_goals: 0,
#                    penalties_missed: 0,
#                    penalties_saved: 0,
#                    red_cards: 0,
#                    saves: 94,
#                    season: 6,
#                    season_name: 2011/12,
#                    start_cost: 70,
#                    threat: 0.0,
#                    total_points: 127,
#                    yellow_cards: 0},
#                   {assists: 0,
#                    bonus: 2,
#                    bps: 0,
#                    clean_sheets: 14,
#                    creativity: 0.0,
#                    ea_index: 502,
#                    element_code: 11334,
#                    end_cost: 64,
#                    goals_conceded: 36,
#                    goals_scored: 0,
#                    ict_index: 0.0,
#                    id: 3991,
#                    influence: 0.0,
#                    minutes: 3195,
#                    own_goals: 0,
#                    penalties_missed: 0,
#                    penalties_saved: 0,
#                    red_cards: 0,
#                    saves: 126,
#                    season: 7,
#                    season_name: 2012/13,
#                    start_cost: 65,
#                    threat: 0.0,
#                    total_points: 144,
#                    yellow_cards: 2},
#                   {assists: 0,
#                    bonus: 1,
#                    bps: 163,
#                    clean_sheets: 16,
#                    creativity: 0.0,
#                    ea_index: 417,
#                    element_code: 11334,
#                    end_cost: 62,
#                    goals_conceded: 24,
#                    goals_scored: 0,
#                    ict_index: 0.0,
#                    id: 4699,
#                    influence: 0.0,
#                    minutes: 3060,
#                    own_goals: 0,
#                    penalties_missed: 0,
#                    penalties_saved: 0,
#                    red_cards: 0,
#                    saves: 82,
#                    season: 8,
#                    season_name: 2013/14,
#                    start_cost: 65,
#                    threat: 0.0,
#                    total_points: 146,
#                    yellow_cards: 0},
#                   {assists: 0,
#                    bonus: 0,
#                    bps: 129,
#                    clean_sheets: 5,
#                    creativity: 0.0,
#                    ea_index: 103,
#                    element_code: 11334,
#                    end_cost: 54,
#                    goals_conceded: 2,
#                    goals_scored: 0,
#                    ict_index: 0.0,
#                    id: 5389,
#                    influence: 0.0,
#                    minutes: 607,
#                    own_goals: 0,
#                    penalties_missed: 0,
#                    penalties_saved: 0,
#                    red_cards: 0,
#                    saves: 16,
#                    season: 9,
#                    season_name: 2014/15,
#                    start_cost: 60,
#                    threat: 0.0,
#                    total_points: 38,
#                    yellow_cards: 0},
#                   {assists: 0,
#                    bonus: 15,
#                    bps: 705,
#                    clean_sheets: 16,
#                    creativity: 0.0,
#                    ea_index: 409,
#                    element_code: 11334,
#                    end_cost: 59,
#                    goals_conceded: 31,
#                    goals_scored: 0,
#                    ict_index: 0.0,
#                    id: 6097,
#                    influence: 0.0,
#                    minutes: 3060,
#                    own_goals: 0,
#                    penalties_missed: 0,
#                    penalties_saved: 0,
#                    red_cards: 0,
#                    saves: 101,
#                    season: 10,
#                    season_name: 2015/16,
#                    start_cost: 55,
#                    threat: 0.0,
#                    total_points: 159,
#                    yellow_cards: 0}],
#  ict_index: 72.8,
#  id: 2,
#  in_dreamteam: False,
#  influence: 707.6,
#  loaned_in: 0,
#  loaned_out: 0,
#  loans_in: 0,
#  loans_out: 0,
#  minutes: 3060,
#  news: ,
#  now_cost: 55,
#  own_goals: 0,
#  penalties_missed: 0,
#  penalties_saved: 0,
#  photo: 11334.jpg,
#  points_per_game: 4.7,
#  red_cards: 0,
#  saves: 101,
#  second_name: Cech,
#  selected_by_percent: 18.9,
#  special: False,
#  squad_number: 33,
#  status: a,
#  team: 1,
#  threat: 0.0,
#  total_points: 159,
#  transfers_in: 0,
#  transfers_in_event: 0,
#  transfers_out: 0,
#  transfers_out_event: 0,
#  value_form: 0.0,
#  value_season: 0.0,
#  web_name: Cech,
#  yellow_cards: 0}

# %%
class Seasons(object):
# This class will return a list of each player's seasons.  Access a particular season and statistic:
# by using: Seasons[x].name 

    def __init__(self, game_json):
        self.name = u"{season_name}".format(**game_json)
        self.points = game_json['total_points']
        self.minutes = game_json['minutes']
        self.start_cost = game_json['start_cost']
        self.end_cost = game_json['end_cost']
    
    def __repr__(self):
        return "%s Season: %s pts, %s min., GBP %s" % (self.name, self.points, self.minutes, self.end_cost
                                                      )
class Player(object):
#This class will return a series of player statistics.

    def __init__(self, player_json):
        self.raw = player_json
        self.seasons = [Seasons(s) for s in player_json['history_past']]
        self.games = ''
        self.name = u'{first_name} {second_name}'.format(**player_json)
        self.cost = player_json['now_cost']
        self.position = position_title[player_json['element_type']]
        self.team = teams[player_json['team']]
        self.idn = player_json['id']
        self.status = player_json['status']
        self.news = player_json['news']
        self.pts = player_json['total_points']
        self.selected_percent = ''
        
    def get_upcoming_fixtures(self,fixtures):
        upcoming = []
        for _, gameweek, opponent in fixtures:
            week = int(gameweek.split()[-1])
            if opponent == '-':
                continue
            opp, loc=opponent.split('(')
#            opp = teams[fixtures['a_team']]
            loc = [0]
            upcoming.append((week, opp, loc))
        return upcoming

# %%
MyPrettyPrinter().pprint(Player(all_data[1]).name)
MyPrettyPrinter().pprint(Player(all_data[1]).seasons[1].minutes)
# Out:
# Petr Cech
# 2313

# %%
print(Seasons(all_data[1]['history_past'][1]))
# Out:
# 2007/08 Season: 120 pts, 2313 min., GBP 65

# %%
# Out:
# {u'yellow_cards': 0, u'goals_conceded': 17, u'saves': 60, u'influence': u'0.0', u'goals_scored': 0, u'id': 807, u'own_goals': 0, u'creativity': u'0.0', u'end_cost': 65, u'ict_index': u'0.0', u'season': 2, u'total_points': 120, u'penalties_missed': 0, u'start_cost': 65, u'element_code': 11334, u'bonus': 2, u'season_name': u'2007/08', u'clean_sheets': 0, u'assists': 0, u'ea_index': 0, u'penalties_saved': 0, u'minutes': 2313, u'bps': 0, u'threat': u'0.0', u'red_cards': 0}

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/Matt/anaconda3/envs/Python2.7/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     668                 type_pprinters=self.type_printers,
#     669                 deferred_pprinters=self.deferred_printers)
# --> 670             printer.pretty(obj)
#     671             printer.flush()
#     672             return stream.getvalue()
#
# /Users/Matt/anaconda3/envs/Python2.7/lib/python2.7/site-packages/IPython/lib/pretty.pyc in pretty(self, obj)
#     381                             if callable(meth):
#     382                                 return meth(obj, self, cycle)
# --> 383             return _default_pprint(obj, self, cycle)
#     384         finally:
#     385             self.end_group()
#
# /Users/Matt/anaconda3/envs/Python2.7/lib/python2.7/site-packages/IPython/lib/pretty.pyc in _default_pprint(obj, p, cycle)
#     501     if _safe_getattr(klass, '__repr__', None) not in _baseclass_reprs:
#     502         # A user-provided repr. Find newlines and replace them with p.break_()
# --> 503         _repr_pprint(obj, p, cycle)
#     504         return
#     505     p.begin_group(1, '<')
#
# /Users/Matt/anaconda3/envs/Python2.7/lib/python2.7/site-packages/IPython/lib/pretty.pyc in _repr_pprint(obj, p, cycle)
#     692     """A pprint that just redirects to the normal repr function."""
#     693     # Find newlines and replace them with p.break_()
# --> 694     output = repr(obj)
#     695     for idx,output_line in enumerate(output.splitlines()):
#     696         if idx:
#
# <ipython-input-31-1f0da9dd2f45> in __repr__(self)
#       8
#       9     def __repr__(self):
# ---> 10         return "%s Season: %s pts, %s min., GBP %s" % (self.name, self.points, self.minutes, self.end_cost
#      11                                                       )
#      12 class Player(object):
#
# AttributeError: 'Seasons' object has no attribute 'name'
